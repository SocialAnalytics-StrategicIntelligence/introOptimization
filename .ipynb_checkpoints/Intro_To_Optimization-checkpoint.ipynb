# %% [markdown]
# <img src="https://i.imgur.com/6U6q5jQ.png"/>
#
# _____
# <a id='home'></a>
#
# <a target="_blank" href="https://colab.research.google.com/github/SocialAnalytics-StrategicIntelligence/introOptimization/blob/main/Intro_To_Optimization.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
#
# # Introduction to Optimization for Decision Making

# %%
# %%html
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vQHq0p2eTmxRWJjDmo1mUmdarYgIrEew4ieiVbIGQy-D_CyBw5rbbRUlRxwLKKaVQpRV9Hs8MGnz0X2/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>
# Out:
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vQHq0p2eTmxRWJjDmo1mUmdarYgIrEew4ieiVbIGQy-D_CyBw5rbbRUlRxwLKKaVQpRV9Hs8MGnz0X2/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>

# %% [markdown]
# # Part 1: Maximization/Minimization

# %% [markdown]
# Please, go to your _environment_ in Anacoda Navigator to install **glpk** and **pulp**  before runing the codes below.
# Then, call the library:

# %%
# pip show glpk pulp
# pip install glpk pulp

# %%
import pulp as pp

# %% [markdown]
# 1. **Initialize the MODEL**: just write the name and declare if it is maximization or minimization problem type.

# %%
model = pp.LpProblem(name='refinery-problem', # just the name
                     sense=pp.LpMaximize) # type of problem

# %% [markdown]
# 2. **Declare the VARIABLES**: The refinery model consists of these _variables_:

# %%
# how much gas?
Gas = pp.LpVariable(name="Gas",  # just the name
                    lowBound=0,  # ensure non-negativity
                    cat='Continuous') # here: you accept decimal values

# how much oil?
Oil = pp.LpVariable(name="Oil",
                 lowBound=0,
                 cat='Continuous')

# %% [markdown]
# 3. **Create function to OPTIMIZE**: The function is just the linear combination of the variables and their _given coefficients__:

# %%
GasCoeff=1.9
OilCoeff=1.5
obj_func = GasCoeff*Gas + OilCoeff*Oil

# %% [markdown]
# 4. **Represent the constraints**: These are the rules the model (set of variables) must obey:

# %%
# SUBJECT TO:
C1= pp.LpConstraint(name='Gas Constraint',   # just the name
                    e= 1*Gas - 2*Oil, rhs=0, # linear combination of constraint and rhs 
                    sense=pp.LpConstraintGE) # 'rule' >= 0 (LpConstraintGE)
C2= pp.LpConstraint(name='Oil Constraint',
                    e= 1*Oil, rhs=3000000,
                    sense=pp.LpConstraintGE) # 'rule' >= 3000000 (LpConstraintGE)
C3= pp.LpConstraint(name='Demand Constraint',
                    e= 1*Gas, rhs=6400000,
                    sense=pp.LpConstraintLE, )# 'rule' <= 6400000 (LpConstraintLE)

# %% [markdown]
# 5. **Build MODEL**: Here you add (i) the objective function, and (ii) all the constraints:

# %%
model += obj_func
model += C1
model += C2
model += C3

# %% [markdown]
# 6. **Solve the MODEL**: Notice we are not using the _default solver_, we are explicitly usig **COIN_CMD**:

# %%
solver_list = pp.listSolvers()
print(solver_list)
# Out:
# ['GLPK_CMD', 'PYGLPK', 'CPLEX_CMD', 'CPLEX_PY', 'GUROBI', 'GUROBI_CMD', 'MOSEK', 'XPRESS', 'XPRESS', 'XPRESS_PY', 'PULP_CBC_CMD', 'COIN_CMD', 'COINMP_DLL', 'CHOCO_CMD', 'MIPCL_CMD', 'SCIP_CMD', 'FSCIP_CMD', 'SCIP_PY', 'HiGHS', 'HiGHS_CMD', 'COPT', 'COPT_DLL', 'COPT_CMD']

# %%
solverToUse = pp.COIN_CMD(msg=False)
model.solve(solver=solverToUse);

# %% [markdown]
# You can create a summary like this:

# %%
import pandas as pd

Results={"Model Status":pp.LpStatus[model.status]}
Results.update({"Optimal Solution":pp.value(model.objective)})
Results.update({v.name: v.varValue for v in model.variables()})
Results
# Out:
# {'Model Status': 'Optimal',
#  'Optimal Solution': 16960000.0,
#  'Gas': 6400000.0,
#  'Oil': 3200000.0}

# %%
#or
pd.DataFrame.from_dict(Results,orient='index').T.set_index('Model Status').style.format('{:,}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_eb210">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eb210_level0_col0" class="col_heading level0 col0" >Optimal Solution</th>
#       <th id="T_eb210_level0_col1" class="col_heading level0 col1" >Gas</th>
#       <th id="T_eb210_level0_col2" class="col_heading level0 col2" >Oil</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Model Status</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eb210_level0_row0" class="row_heading level0 row0" >Optimal</th>
#       <td id="T_eb210_row0_col0" class="data row0 col0" >16,960,000.0</td>
#       <td id="T_eb210_row0_col1" class="data row0 col1" >6,400,000.0</td>
#       <td id="T_eb210_row0_col2" class="data row0 col2" >3,200,000.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# <div class="alert-success">
#
# <strong>Exercise: The diet problem</strong>

# %%
# %%html
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vTSq9X74urGAB_5n_MIJ9ZGIboKSvBdokVTBXVLh_qqZnmLRTJioOF431Rzys3Qi9UaFwWXjeq6Wmd5/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>
# Out:
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vTSq9X74urGAB_5n_MIJ9ZGIboKSvBdokVTBXVLh_qqZnmLRTJioOF431Rzys3Qi9UaFwWXjeq6Wmd5/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>

# %% [markdown]
# # Part 2: Multicriteria Decision-Making

# %%
# %%html
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vR7GL_wF1eKRO0JgEUyIx5cxXUhTQ8ZM4F3AE1MLr7GYG33dwEobrLo6O2MaV2d7Cv47TaTgHghkhrV/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>
# Out:
# <iframe src="https://docs.google.com/presentation/d/e/2PACX-1vR7GL_wF1eKRO0JgEUyIx5cxXUhTQ8ZM4F3AE1MLr7GYG33dwEobrLo6O2MaV2d7Cv47TaTgHghkhrV/embed?start=false&loop=false&delayms=3000" frameborder="0" width="960" height="569" allowfullscreen="true" mozallowfullscreen="true" webkitallowfullscreen="true"></iframe>

# %% [markdown]
# 1. Prepare data file with the comparissons:

# %%
# %%html
#
# <iframe src="https://docs.google.com/spreadsheets/d/e/2PACX-1vSeUfh-DtfAAvEecirNS7Qs2qN4npmNfRiw9JvKmRpq88snVc8HJBlru2cyPy8lsQflSxlnx6U-IePw/pubhtml?widget=true&amp;headers=false" width="600" height="300" ></iframe>
# Out:
# <iframe src="https://docs.google.com/spreadsheets/d/e/2PACX-1vSeUfh-DtfAAvEecirNS7Qs2qN4npmNfRiw9JvKmRpq88snVc8HJBlru2cyPy8lsQflSxlnx6U-IePw/pubhtml?widget=true&amp;headers=false" width="600" height="300" ></iframe>

# %% [markdown]
# 2. Get the data (Excel)

# %%
# the link to the data

linkGoogle='https://docs.google.com/spreadsheets/d/e/2PACX-1vSeUfh-DtfAAvEecirNS7Qs2qN4npmNfRiw9JvKmRpq88snVc8HJBlru2cyPy8lsQflSxlnx6U-IePw/pub?output=xlsx'# the link to the data

# %% [markdown]
# 3. Open each sheet:

# %%
# opening the comparissons

import pandas as pd

pairwise_age=pd.read_excel(linkGoogle,sheet_name='age', index_col=0)
pairwise_experience=pd.read_excel(linkGoogle,sheet_name='experience', index_col=0)
pairwise_education=pd.read_excel(linkGoogle,sheet_name='education', index_col=0)
pairwise_charisma=pd.read_excel(linkGoogle,sheet_name='charisma', index_col=0)
pairwise_criteria=pd.read_excel(linkGoogle,sheet_name='criteria', index_col=0)

# %% [markdown]
# You may want to check the structure:

# %%
pairwise_criteria
# Out:
#             experience  education  charisma  age
# experience    1.000000   4.000000  3.000000    7
# education     0.250000   1.000000  0.333333    3
# charisma      0.333333   3.000000  1.000000    5
# age           0.142857   0.333333  0.200000    1

# %% [markdown]
# 4. Transform all matrices into pairwise comparissons:

# %%
import networkx as nx

G_age = nx.from_pandas_adjacency(pairwise_age,create_using=nx.MultiDiGraph())

# pairwise
G_age.edges(data=True)
# Out:
# OutMultiEdgeDataView([('Tom', 'Tom', {'weight': 1.0}), ('Tom', 'Dick', {'weight': 0.3333333333}), ('Tom', 'Harry', {'weight': 5.0}), ('Dick', 'Dick', {'weight': 1.0}), ('Dick', 'Tom', {'weight': 3.0}), ('Dick', 'Harry', {'weight': 9.0}), ('Harry', 'Harry', {'weight': 1.0}), ('Harry', 'Tom', {'weight': 0.2}), ('Harry', 'Dick', {'weight': 0.1111111111})])

# %%
# comparissons for age as dict
age_comparisons ={(e[0],e[1]):e[2]['weight'] for e in G_age.edges(data=True) if e[0]!= e[1]}
age_comparisons
# Out:
# {('Tom', 'Dick'): 0.3333333333,
#  ('Tom', 'Harry'): 5.0,
#  ('Dick', 'Tom'): 3.0,
#  ('Dick', 'Harry'): 9.0,
#  ('Harry', 'Tom'): 0.2,
#  ('Harry', 'Dick'): 0.1111111111}

# %%
# the remaining comparissons:

G_exp = nx.from_pandas_adjacency(pairwise_experience,create_using=nx.MultiDiGraph())
experience_comparisons={(e[0],e[1]):e[2]['weight'] for e in G_exp.edges(data=True) if e[0]!= e[1]}

G_edu = nx.from_pandas_adjacency(pairwise_education,create_using=nx.MultiDiGraph())
education_comparisons={(e[0],e[1]):e[2]['weight'] for e in G_edu.edges(data=True) if e[0]!= e[1]}

G_cha = nx.from_pandas_adjacency(pairwise_charisma,create_using=nx.MultiDiGraph())
charisma_comparisons={(e[0],e[1]):e[2]['weight'] for e in G_cha.edges(data=True) if e[0]!= e[1]}

# %%
# take a look
[age_comparisons, experience_comparisons,education_comparisons,charisma_comparisons]
# Out:
# [{('Tom', 'Dick'): 0.3333333333,
#   ('Tom', 'Harry'): 5.0,
#   ('Dick', 'Tom'): 3.0,
#   ('Dick', 'Harry'): 9.0,
#   ('Harry', 'Tom'): 0.2,
#   ('Harry', 'Dick'): 0.1111111111},
#  {('Tom', 'Dick'): 0.25,
#   ('Tom', 'Harry'): 4.0,
#   ('Dick', 'Tom'): 4.0,
#   ('Dick', 'Harry'): 9.0,
#   ('Harry', 'Tom'): 0.25,
#   ('Harry', 'Dick'): 0.1111111111},
#  {('Tom', 'Dick'): 3.0,
#   ('Tom', 'Harry'): 0.2,
#   ('Dick', 'Tom'): 0.3333333333,
#   ('Dick', 'Harry'): 0.1428571429,
#   ('Harry', 'Tom'): 5.0,
#   ('Harry', 'Dick'): 7.0},
#  {('Tom', 'Dick'): 5.0,
#   ('Tom', 'Harry'): 9.0,
#   ('Dick', 'Tom'): 0.2,
#   ('Dick', 'Harry'): 4.0,
#   ('Harry', 'Tom'): 0.1111111111,
#   ('Harry', 'Dick'): 0.25}]

# %%
# now the criteria

G_CRIT = nx.from_pandas_adjacency(pairwise_criteria,create_using=nx.MultiDiGraph())
criteria_comparisons ={(e[0],e[1]):e[2]['weight'] for e in G_CRIT.edges(data=True) if e[0]!= e[1]}
criteria_comparisons
# Out:
# {('experience', 'education'): 4.0,
#  ('experience', 'charisma'): 3.0,
#  ('experience', 'age'): 7.0,
#  ('education', 'experience'): 0.25,
#  ('education', 'charisma'): 0.3333333333,
#  ('education', 'age'): 3.0,
#  ('charisma', 'experience'): 0.3333333333,
#  ('charisma', 'education'): 3.0,
#  ('charisma', 'age'): 5.0,
#  ('age', 'experience'): 0.1428571429,
#  ('age', 'education'): 0.3333333333,
#  ('age', 'charisma'): 0.2}

# %% [markdown]
# 5. Apply the Algorithm

# %%
## install
# !pip install ahpy

# %%
# input each comparisson

import ahpy

experience = ahpy.Compare('experience', experience_comparisons, precision=3, random_index='saaty')
education = ahpy.Compare('education', education_comparisons, precision=3, random_index='saaty')
charisma = ahpy.Compare('charisma', charisma_comparisons, precision=3, random_index='saaty')
age = ahpy.Compare('age', age_comparisons, precision=3, random_index='saaty')
criteria = ahpy.Compare('criteria', criteria_comparisons, precision=3, random_index='saaty')

# %% [markdown]
# 6. Create hierarchy:

# %%
criteria.add_children([experience, education, charisma, age])

# %% [markdown]
# 7. See result:

# %%
print(criteria.target_weights)
# Out:
# {'Dick': 0.493, 'Tom': 0.358, 'Harry': 0.15}

# %% [markdown]
# 8. Assess consistency

# %%
## We should review comparissons if greater than 0.1!
[(val.name,val.consistency_ratio) for val in [experience, education, charisma, age, criteria]]
# Out:
# [('experience', 0.035),
#  ('education', 0.062),
#  ('charisma', 0.069),
#  ('age', 0.028),
#  ('criteria', 0.044)]

# %% [markdown]
# <div class="alert-success">
#
# <strong>Exercise: Choosing a country for a Master Program</strong>
#
# - Make a group of 4 people from this course.
# - If you have the criteria: cost of living, language difficulty, possibilities to get a job in that country after studies are finished.
# - If you have the alternatives: Brazil, Spain, USA, Germany.
# - Create an AHP model and get the ranking.
#
# You can follow this [example](https://en.wikipedia.org/wiki/Analytic_hierarchy_process_%E2%80%93_leader_example).
# If you have a better idea, you can use it instead.

# %% [markdown]
# # Part 3: Benchmarking

# %% [markdown]
# Imagine you have this information:

# %%
airline=pd.read_csv("airlines_data.csv")
airline
# Out:
#    name  Aircraft  Fuel  Employee  Passenger  Freight
# 0     A       109   392      8259      23756      870
# 1     B       115   381      9628      24183     1359
# 2     C       767  2673     70923     163483    12449
# 3     D        90   282      9683      10370      509
# 4     E       461  1608     40630      99047     3726
# 5     F       628  2074     47420     128635     9214
# 6     G        81    75      7115      11962      536
# 7     I       153   458     10177      32436     1462
# 8     J       455  1722     29124      83862     6337
# 9     K       103   400      8987      14618      785
# 10    L       547  1217     34680      99636     6597
# 11    M       560  2532     51536     135480    10928
# 12    N       423  1303     32683      74106     4258

# %% [markdown]
# The first three variables (Aircraft,Fuel,Employee) represent **inputs** and the last two ones represent **outputs**. If that is so, there should be a way to compute some measure of efficiency: the ratio **output/input**.
#
# Let's compute some ratios:

# %%
# ratio passenger employee:
airline['rate_ClientsByEmployee']=(airline.Passenger/airline.Employee)
airline['rate_CargoByFleet']=(airline.Freight/airline.Aircraft)

# %% [markdown]
# Let me plot those ratios:

# %%
import altair as alt

points = alt.Chart(airline).mark_point().encode(
    x='rate_ClientsByEmployee:Q',
    y='rate_CargoByFleet:Q'
)

text = points.mark_text(
    align='right',
    baseline='middle',
    dx=-7
).encode(
    text='name'
).interactive()

points + text
# Out:
# alt.LayerChart(...)

# %% [markdown]
# Which one is more efficient? As you see, one airline might not be good in both ratios:

# %%
airline[['name','rate_ClientsByEmployee','rate_CargoByFleet']].sort_values(by='rate_ClientsByEmployee',ascending=False).head()
# Out:
#    name  rate_ClientsByEmployee  rate_CargoByFleet
# 7     I                3.187187           9.555556
# 8     J                2.879481          13.927473
# 0     A                2.876377           7.981651
# 10    L                2.873010          12.060329
# 5     F                2.712674          14.671975

# %%
airline[['name','rate_ClientsByEmployee','rate_CargoByFleet']].sort_values(by='rate_CargoByFleet',ascending=False).head()
# Out:
#    name  rate_ClientsByEmployee  rate_CargoByFleet
# 11    M                2.628842          19.514286
# 2     C                2.305077          16.230769
# 5     F                2.712674          14.671975
# 8     J                2.879481          13.927473
# 10    L                2.873010          12.060329

# %% [markdown]
# Let me show you the **envelope**:

# %%
Best_ClientsByEmployee=airline.rate_ClientsByEmployee.idxmax()
Best_CargoByFleet=airline.rate_CargoByFleet.idxmax()

frontier1=airline.loc[Best_ClientsByEmployee,['rate_ClientsByEmployee','rate_CargoByFleet']].to_list()
frontier2=airline.loc[Best_CargoByFleet,['rate_ClientsByEmployee','rate_CargoByFleet']].to_list()

#parallels
frontier1v=[frontier1[0],0]
frontier2h=[0,frontier2[1]]

#then
envelope=pd.DataFrame([frontier2h,frontier2,frontier1,frontier1v],columns=['x','y'])
envelope
# Out:
#           x          y
# 0  0.000000  19.514286
# 1  2.628842  19.514286
# 2  3.187187   9.555556
# 3  3.187187   0.000000

# %% [markdown]
# Updating the plot:

# %%
points + text + alt.Chart(envelope).mark_line(color='red').encode(
    x='x',
    y='y',
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# The presence of several units (DMUs), several inputs, and several outputs makes it difficult to judge who is doing better. This an optimization problem that may be carried out using **Pyfrontier**:

# %%
## installation
# pip install Pyfrontier

# %%
from Pyfrontier.frontier_model import EnvelopDEA

dea_crs_in = EnvelopDEA("CRS", "in")
crs_in_fit=dea_crs_in.fit(
    inputs=airline[['Aircraft','Fuel','Employee']].to_numpy(),
    outputs=airline[['Passenger','Freight']].to_numpy()
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/e364b8fd165749a18b7f67ab4c472873-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/e364b8fd165749a18b7f67ab4c472873-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 6.8188776 - largest nonzero change 5.5864155e-05 ( 0.00081925734%) - largest zero change 5.3045592e-05
# 0  Obj 0 Primal inf 0.21519668 (2)
# 4  Obj 0.97797507
# Optimal - objective value 0.97796189
# Optimal objective 0.9779618935 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/3320500a0bea466980ac3bfc5d6a0385-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/3320500a0bea466980ac3bfc5d6a0385-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 49.055024 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 49.055024 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj 14.265853 Primal inf 0.40013528 (2)
# Primal infeasible - objective value 14.265853
# PrimalInfeasible objective 14.26585258 - 7 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/864c7030ed10471c9d89bb026d1e7656-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/864c7030ed10471c9d89bb026d1e7656-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 6.6695652 - largest nonzero change 5.4784802e-05 ( 0.00082141489%) - largest zero change 5.2574671e-05
# 0  Obj 0 Primal inf 0.25708883 (2)
# 6  Obj 0.96841629
# Optimal - objective value 0.96840307
# Optimal objective 0.9684030659 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/fe80da27e1ce4d1baf643b8d84f6f5cd-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/fe80da27e1ce4d1baf643b8d84f6f5cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 52.591051 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 52.591051 (6) Dual inf 4.9977534e+11 (16)
# 8  Obj -113.93749 Primal inf 0.7011593 (2)
# Primal infeasible - objective value -113.93749
# PrimalInfeasible objective -113.9374915 - 8 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/c65e1c870b664fce8c4a07c1b800a6a1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/c65e1c870b664fce8c4a07c1b800a6a1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1 - largest nonzero change 1.380049e-05 ( 0.001380049%) - largest zero change 1.2678383e-05
# 0  Obj 0 Primal inf 1.9999998 (2)
# 4  Obj 1.0000242
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/b1f156cee8734e4581d3ac4533e516ad-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/b1f156cee8734e4581d3ac4533e516ad-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 322.39806 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 322.39806 (6) Dual inf 4.9977534e+11 (16)
# 9  Obj 3.9236477e-10
# Optimal - objective value 3.0857775e-10
# Optimal objective 3.085777538e-10 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/833c4911860140359cb4ea03a06b84d9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/833c4911860140359cb4ea03a06b84d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 7.3244862 - largest nonzero change 5.9519113e-05 ( 0.00081260461%) - largest zero change 5.9112649e-05
# 0  Obj 0 Primal inf 0.10431829 (2)
# 6  Obj 0.53690185
# Optimal - objective value 0.53689514
# Optimal objective 0.5368951366 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/95e00588e4bd4162aa50346e219c0e67-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/95e00588e4bd4162aa50346e219c0e67-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 29.309682 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 29.309682 (6) Dual inf 4.9977534e+11 (16)
# 4  Obj 46.257497 Primal inf 4.0012625 (3)
# Primal infeasible - objective value 46.257497
# PrimalInfeasible objective 46.25749738 - 4 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/e42fbb11bc4d41bb8fcd001e976bfdb5-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/e42fbb11bc4d41bb8fcd001e976bfdb5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1.6623134 - largest nonzero change 1.858824e-05 ( 0.0011182151%) - largest zero change 1.839107e-05
# 0  Obj 0 Primal inf 0.90515599 (2)
# 5  Obj 0.96918467
# Optimal - objective value 0.96916635
# Optimal objective 0.9691663537 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f29214f0c2d6420d8d091cb20ba9d2a4-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f29214f0c2d6420d8d091cb20ba9d2a4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 176.88243 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 176.88243 (6) Dual inf 4.9977534e+11 (16)
# 9  Obj 7569.7506 Primal inf 1.4178797 (1)
# Primal infeasible - objective value 7569.7506
# PrimalInfeasible objective 7569.75057 - 9 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/0c6642736c844b578e62033c6f3065b7-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/0c6642736c844b578e62033c6f3065b7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1.2213376 - largest nonzero change 1.5400501e-05 ( 0.0012609537%) - largest zero change 1.4828878e-05
# 0  Obj 0 Primal inf 1.5269798 (2)
# 8  Obj 0.9779775
# Optimal - objective value 0.97795541
# Optimal objective 0.9779554074 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/189c4ad4851c412081f72f1398491184-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/189c4ad4851c412081f72f1398491184-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 242.37277 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 242.37277 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj -1819.2282 Primal inf 1.6498442 (2)
# Primal infeasible - objective value -1819.2282
# PrimalInfeasible objective -1819.228231 - 7 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6f5fc131420646d2898b790a13a07e2e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6f5fc131420646d2898b790a13a07e2e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 9.4691358 - largest nonzero change 7.5022416e-05 ( 0.00079228366%) - largest zero change 7.3458333e-05
# 0  Obj 0 Primal inf 0.11622515 (2)
# 6  Obj 1.000012
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6f9a58b5d0714769bd8bdf1c4f26b5a5-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6f9a58b5d0714769bd8bdf1c4f26b5a5-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 31.936706 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 31.936706 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj 4.1928394e-11
# Optimal - objective value 1.1486684e-10
# Optimal objective 1.148668402e-10 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/687135afbbec4968b59745a21f42e615-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/687135afbbec4968b59745a21f42e615-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 5.0130719 - largest nonzero change 4.2810296e-05 ( 0.00085397332%) - largest zero change 3.9679229e-05
# 0  Obj 0 Primal inf 0.3158449 (2)
# 4  Obj 1.0000149
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6e0cb19c1a9345219260cc2f5455923a-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6e0cb19c1a9345219260cc2f5455923a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 62.30023 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 62.30023 (6) Dual inf 4.9977534e+11 (16)
# 9  Obj 7.7592021e-10
# Optimal - objective value 7.7592021e-10
# Optimal objective 7.759202064e-10 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/68ce3496c1644a85947dcc2728700679-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/68ce3496c1644a85947dcc2728700679-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1.5522648 - largest nonzero change 1.7792717e-05 ( 0.0011462424%) - largest zero change 1.5266195e-05
# 0  Obj 0 Primal inf 1.0220074 (2)
# 8  Obj 1.0000187
# Optimal - objective value 1
# Optimal objective 1 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/03fed4d4c5ae45bca2a1bdd7a9c5696c-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/03fed4d4c5ae45bca2a1bdd7a9c5696c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 173.44772 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 173.44772 (6) Dual inf 4.9977534e+11 (16)
# 11  Obj 1.3911408e-09
# Optimal - objective value 1.3577677e-09
# Optimal objective 1.357767665e-09 - 11 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/2fd9511337dd4f8690805d6f791d135c-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/2fd9511337dd4f8690805d6f791d135c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 6.6825 - largest nonzero change 5.4878305e-05 ( 0.00082122417%) - largest zero change 5.2615466e-05
# 0  Obj 0 Primal inf 0.1524731 (2)
# 5  Obj 0.61858612
# Optimal - objective value 0.61857792
# Optimal objective 0.6185779156 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f222172d605d43d1a60f5b477bc40f32-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f222172d605d43d1a60f5b477bc40f32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 36.091529 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 36.091529 (6) Dual inf 4.9977534e+11 (16)
# 5  Obj 25.968298 Primal inf 4.5330323 (3)
# Primal infeasible - objective value 25.968298
# PrimalInfeasible objective 25.9682976 - 5 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/8762ed7471a4443d890b6580eee98ded-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/8762ed7471a4443d890b6580eee98ded-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1.4021938 - largest nonzero change 1.670788e-05 ( 0.0011915528%) - largest zero change 1.5067878e-05
# 0  Obj 0 Primal inf 1.1393797 (2)
# 6  Obj 1.0000202
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/8443cfe34ec9448aa3ed31e284dc9067-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/8443cfe34ec9448aa3ed31e284dc9067-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 181.40469 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 181.40469 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj -0
# Optimal - objective value -5.7427304e-13
# Optimal objective -5.742730371e-13 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/35230f3fd3d94738a6840997fb005a90-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/35230f3fd3d94738a6840997fb005a90-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1.0556872 - largest nonzero change 1.4203043e-05 ( 0.0013453837%) - largest zero change 1.2742567e-05
# 0  Obj 0 Primal inf 1.7065313 (2)
# 3  Obj 1.0000229
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/7bb28cbc68e143eab5b0ee569b0fe154-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/7bb28cbc68e143eab5b0ee569b0fe154-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 268.17987 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 268.17987 (6) Dual inf 4.9977534e+11 (16)
# 10  Obj 3.1293939e-10
# Optimal - objective value 3.1293939e-10
# Optimal objective 3.129393871e-10 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6d297957d5134ac3a921f9d6ae3087fc-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6d297957d5134ac3a921f9d6ae3087fc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 10 COLUMNS
# At line 80 RHS
# At line 86 BOUNDS
# At line 87 ENDATA
# Problem MODEL has 5 rows, 14 columns and 68 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 5 (0) rows, 14 (0) columns and 68 (0) elements
# Perturbing problem by 0.001% of 1.8132388 - largest nonzero change 1.9679253e-05 ( 0.0010853095%) - largest zero change 1.8629074e-05
# 0  Obj 0 Primal inf 0.79533014 (2)
# 6  Obj 0.83470881
# Optimal - objective value 0.8346939
# Optimal objective 0.8346939045 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/947169196172421bb61d565feee88567-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/947169196172421bb61d565feee88567-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 138.1679 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 138.1679 (6) Dual inf 4.9977534e+11 (16)
# 8  Obj 1914.1895 Primal inf 0.42104894 (1)
# Primal infeasible - objective value 1914.1895
# PrimalInfeasible objective 1914.189514 - 8 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
airline['crs_in']=[r.score for r in dea_crs_in.result]
airline.loc[:,['name','crs_in']]
# Out:
#    name    crs_in
# 0     A  0.977962
# 1     B  0.968403
# 2     C  1.000000
# 3     D  0.536895
# 4     E  0.969166
# 5     F  0.977955
# 6     G  1.000000
# 7     I  1.000000
# 8     J  1.000000
# 9     K  0.618578
# 10    L  1.000000
# 11    M  1.000000
# 12    N  0.834694

# %%
airline[['Aircraft_sl_crs_in','Fuel_sl_crs_in','Employee_sl_crs_in']]=[[round(v,2) for v in r.x_slack] for r in dea_crs_in.result]
airline[['Passenger_sl_crs_in','Freight_sl_crs_in']]=[[round(v,2) for v in r.y_slack] for r in dea_crs_in.result]
airline['efficient_crs_in']=[r.is_efficient for r in dea_crs_in.result]
airline.set_index('name').loc[:,'crs_in':]
# Out:
#         crs_in  Aircraft_sl_crs_in  Fuel_sl_crs_in  Employee_sl_crs_in  \
# name
# A     0.977962               -3.61            0.00                0.00
# B     0.968403                0.00            0.00                0.00
# C     1.000000                0.00            0.00                0.00
# D     0.536895                0.00           46.26                0.00
# E     0.969166                0.00            0.00             4280.57
# F     0.977955                0.00           39.89                0.00
# G     1.000000               -0.00            0.00                0.00
# I     1.000000               -0.00            0.00               -0.00
# J     1.000000                0.00            0.00               -0.00
# K     0.618578                0.00           25.97                0.00
# L     1.000000                0.00            0.00                0.00
# M     1.000000               -0.00            0.00                0.00
# N     0.834694                0.00            0.00             1247.98
#
#       Passenger_sl_crs_in  Freight_sl_crs_in  efficient_crs_in
# name
# A                    0.00              17.88             False
# B                    0.00            -113.94             False
# C                   -0.00              -0.00             False
# D                    0.00               0.00             False
# E                    0.00            3289.18             False
# F                -1859.11               0.00             False
# G                    0.00               0.00             False
# I                    0.00               0.00             False
# J                    0.00               0.00             False
# K                    0.00               0.00             False
# L                    0.00              -0.00              True
# M                    0.00              -0.00             False
# N                    0.00             666.21             False

# %%
dea_vrs_in = EnvelopDEA("VRS", "in")
vrs_in_fit=dea_vrs_in.fit(
    inputs=airline[['Aircraft','Fuel','Employee']].to_numpy(),
    outputs=airline[['Passenger','Freight']].to_numpy()
)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/1afb83c08702402d89d028fe55f43d37-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/1afb83c08702402d89d028fe55f43d37-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 1.142205 - largest nonzero change 1.4828465e-05 ( 0.0012982315%) - largest zero change 1.4724305e-05
# 0  Obj 0 Primal inf 1.967037 (3)
# 5  Obj 1.0000248
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ef4e4c324c0b46a090623cf13ed33605-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ef4e4c324c0b46a090623cf13ed33605-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 49.543773 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 49.543773 (6) Dual inf 4.9977534e+11 (16)
# 11  Obj 3.4459553e-09
# Optimal - objective value 3.4459553e-09
# Optimal objective 3.445955314e-09 - 11 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/4a57ac3734704326bdbebe4ddec1ea9e-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/4a57ac3734704326bdbebe4ddec1ea9e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 1.175182 - largest nonzero change 1.5066851e-05 ( 0.0012820865%) - largest zero change 1.4767884e-05
# 0  Obj 0 Primal inf 2.1815284 (3)
# 7  Obj 1.0000276
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/bfd8f7611fd743fbb2800397ace24520-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/bfd8f7611fd743fbb2800397ace24520-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 53.33661 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 53.33661 (6) Dual inf 4.9977534e+11 (16)
# 10  Obj 2.1441112e-09
# Optimal - objective value 2.1441112e-09
# Optimal objective 2.144111187e-09 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ae6437d399bd44e4817716c95f3acdd1-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/ae6437d399bd44e4817716c95f3acdd1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.1675063 - largest nonzero change 7.7825361e-06 ( 0.0046461154%) - largest zero change 6.7181256e-06
# 0  Obj 0 Primal inf 10.345658 (3)
# 4  Obj 1.0000751
# Optimal - objective value 1
# Optimal objective 1 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/51b6d979bd5c4c59aa673e98f22147cc-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/51b6d979bd5c4c59aa673e98f22147cc-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 322.39806 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 322.39806 (6) Dual inf 4.9977534e+11 (16)
# 9  Obj 3.9236477e-10
# Optimal - objective value 3.0857775e-10
# Optimal objective 3.085777538e-10 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/e4c48b3f1c2e4760a853a6f31fc5b8d9-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/e4c48b3f1c2e4760a853a6f31fc5b8d9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 1.5877459 - largest nonzero change 1.8049204e-05 ( 0.0011367816%) - largest zero change 1.5313083e-05
# 0  Obj 0 Primal inf 1.4759424 (3)
# 4  Obj 0.90002182
# Optimal - objective value 0.9
# Optimal objective 0.9 - 4 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/9d5215a7b56044fab019c587e6f05355-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/9d5215a7b56044fab019c587e6f05355-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 36.685189 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 36.685189 (6) Dual inf 4.9977534e+11 (16)
# 8  Obj 3397.5
# Optimal - objective value 3397.5
# Optimal objective 3397.5 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/c2b915c75a39424ca71663818f33415d-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/c2b915c75a39424ca71663818f33415d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.27844798 - largest nonzero change 8.5845144e-06 ( 0.0030829868%) - largest zero change 8.1043808e-06
# 0  Obj 0 Primal inf 5.0729993 (3)
# 6  Obj 0.99560923
# Optimal - objective value 0.99556118
# Optimal objective 0.9955611786 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/7b27351a15d8477f813ee419a29edb70-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/7b27351a15d8477f813ee419a29edb70-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 179.48326 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 179.48326 (6) Dual inf 4.9977534e+11 (16)
# 10  Obj 7868.9291 Primal inf 6.10541e-06 (1)
# 10  Obj 7868.9291 Primal inf 6.10541e-06 (1)
# Primal infeasible - objective value 7868.9291
# PrimalInfeasible objective 7868.92913 - 10 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/88d6983a03964944b9c0c1d215be04ce-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/88d6983a03964944b9c0c1d215be04ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.21588445 - largest nonzero change 8.1322534e-06 ( 0.0037669473%) - largest zero change 8.0550506e-06
# 0  Obj 0 Primal inf 8.111454 (3)
# 8  Obj 1.0000649
# Optimal - objective value 1
# Optimal objective 1 - 8 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f8a91db9cb004b01b8647cc90c44124a-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f8a91db9cb004b01b8647cc90c44124a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 245.09272 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 245.09272 (6) Dual inf 4.9977534e+11 (16)
# 14  Obj 1.2033451e-09
# Optimal - objective value 1.2818933e-09
# Optimal objective 1.28189329e-09 - 14 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/641b2a04262b4161ab248ead096b0a72-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/641b2a04262b4161ab248ead096b0a72-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 2.9091024 - largest nonzero change 2.7601063e-05 ( 0.00094878279%) - largest zero change 2.4353447e-05
# 0  Obj 0 Primal inf 1.5277135 (3)
# 2  Obj 1.0000198
# Optimal - objective value 1
# Optimal objective 1 - 2 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f00b2f3277da432ab44a40b3507f98b6-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/f00b2f3277da432ab44a40b3507f98b6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 31.936706 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 31.936706 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj 4.1928394e-11
# Optimal - objective value 1.1486684e-10
# Optimal objective 1.148668402e-10 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/40408c436c974269937cd9a47c1d49ba-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/40408c436c974269937cd9a47c1d49ba-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.97760774 - largest nonzero change 1.363862e-05 ( 0.0013951015%) - largest zero change 1.1732415e-05
# 0  Obj 0 Primal inf 2.4345181 (3)
# 6  Obj 1.000026
# Optimal - objective value 1
# Optimal objective 1 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/91ccb2bb496e4f9aa356822738a9b573-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/91ccb2bb496e4f9aa356822738a9b573-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 62.30023 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 62.30023 (6) Dual inf 4.9977534e+11 (16)
# 9  Obj 7.7592021e-10
# Optimal - objective value 7.7592021e-10
# Optimal objective 7.759202064e-10 - 9 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/541ca44548d046a8ad08338c396782de-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/541ca44548d046a8ad08338c396782de-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.26001414 - largest nonzero change 8.4512594e-06 ( 0.0032503076%) - largest zero change 8.0898461e-06
# 0  Obj 0 Primal inf 5.7736569 (3)
# 7  Obj 1.0000518
# Optimal - objective value 1
# Optimal objective 1 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/cc23badde09d43c0b2eb12654e93b12f-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/cc23badde09d43c0b2eb12654e93b12f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 173.44772 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 173.44772 (6) Dual inf 4.9977534e+11 (16)
# 11  Obj 1.3911408e-09
# Optimal - objective value 1.3577677e-09
# Optimal objective 1.357767665e-09 - 11 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/c88baedd8af348c992056d9097fc9aaa-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/c88baedd8af348c992056d9097fc9aaa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 1.1193609 - largest nonzero change 1.4663329e-05 ( 0.0013099734%) - largest zero change 1.1883915e-05
# 0  Obj 0 Primal inf 1.6990128 (3)
# 5  Obj 0.88630077
# Optimal - objective value 0.88627918
# Optimal objective 0.8862791822 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6dab002447ba4e239318970f051ef1c7-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/6dab002447ba4e239318970f051ef1c7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 42.209645 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 42.209645 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj 1318.0915 Primal inf 7.0599609e-07 (1)
# 7  Obj 1318.0915 Primal inf 7.0599609e-07 (1)
# Primal infeasible - objective value 1318.0915
# PrimalInfeasible objective 1318.091495 - 7 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/72bc9f66592145e2aa9e62dc12b4748f-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/72bc9f66592145e2aa9e62dc12b4748f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.36790826 - largest nonzero change 9.2312074e-06 ( 0.0025091058%) - largest zero change 9.2267484e-06
# 0  Obj 0 Primal inf 6.2834871 (3)
# 3  Obj 1.0000396
# Optimal - objective value 1
# Optimal objective 1 - 3 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/cff7957e5e6944ffbb23a963fb225bc9-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/cff7957e5e6944ffbb23a963fb225bc9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 181.40469 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 181.40469 (6) Dual inf 4.9977534e+11 (16)
# 7  Obj -0
# Optimal - objective value -5.7427304e-13
# Optimal objective -5.742730371e-13 - 7 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/aa1e508cae944c81acbc582e05185c24-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/aa1e508cae944c81acbc582e05185c24-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.17683426 - largest nonzero change 7.8499663e-06 ( 0.004439166%) - largest zero change 6.724289e-06
# 0  Obj 0 Primal inf 8.999425 (3)
# 5  Obj 1.0000703
# Optimal - objective value 1
# Optimal objective 1 - 5 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/62e03822cdaa4e79a40a8a6a509f9566-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/62e03822cdaa4e79a40a8a6a509f9566-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 268.17987 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 268.17987 (6) Dual inf 4.9977534e+11 (16)
# 10  Obj 3.1293939e-10
# Optimal - objective value 3.1293939e-10
# Optimal objective 3.129393871e-10 - 10 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/7cacad4ed92b46df92f8c5d7486e7603-pulp.mps -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/7cacad4ed92b46df92f8c5d7486e7603-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 94 RHS
# At line 101 BOUNDS
# At line 102 ENDATA
# Problem MODEL has 6 rows, 14 columns and 81 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 14 (0) columns and 81 (0) elements
# Perturbing problem by 0.001% of 0.34362575 - largest nonzero change 9.0556733e-06 ( 0.0026353303%) - largest zero change 8.8233369e-06
# 0  Obj 0 Primal inf 4.6595921 (3)
# 6  Obj 0.84863335
# Optimal - objective value 0.84859847
# Optimal objective 0.8485984692 - 6 iterations time 0.002
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/pulp/solverdir/cbc/osx/64/cbc /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/37126e9f38ec4087b0cb6dcd33ab5ae0-pulp.mps -max -revised -ratio 1e-10 -timeMode elapsed -branch -printingOptions all -solution /var/folders/2n/bkfhfqq16r78g3hf7pdj56y40000gn/T/37126e9f38ec4087b0cb6dcd33ab5ae0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 100 RHS
# At line 107 BOUNDS
# At line 108 ENDATA
# Problem MODEL has 6 rows, 18 columns and 83 elements
# Coin0008I MODEL read with 0 errors
# No match for revised - ? for list of commands
# ratioGap was changed from 0 to 1e-10
# Option for timeMode changed from cpu to elapsed
# Presolve 6 (0) rows, 18 (0) columns and 83 (0) elements
# Perturbing problem by 0.001% of 1813.0942 - largest nonzero change 8.9764456e-05 ( 5.8013528e-05%) - largest zero change 4.8183991e-05
# 0  Obj -0 Primal inf 139.30414 (6) Dual inf 3077.8469 (5)
# 0  Obj -0 Primal inf 139.30414 (6) Dual inf 4.9977534e+11 (16)
# 8  Obj 2324.9368 Primal inf 1.4108706e-05 (1)
# 8  Obj 2324.9368 Primal inf 1.4108706e-05 (1)
# Primal infeasible - objective value 2324.9368
# PrimalInfeasible objective 2324.936781 - 8 iterations time 0.002
#
# Result - Linear relaxation infeasible
#
# Enumerated nodes:           0
# Total iterations:           0
# Time (CPU seconds):         0.00
# Time (Wallclock Seconds):   0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00

# %%
airline['vrs_in']=[r.score for r in dea_vrs_in.result]
airline[['Aircraft_sl_vrs_in','Fuel_sl_vrs_in','Employee_sl_vrs_in']]=[[round(v,2) for v in r.x_slack] for r in dea_vrs_in.result]
airline[['Passenger_sl_vrs_in','Freight_sl_vrs_in']]=[[round(v,2) for v in r.y_slack] for r in dea_vrs_in.result]
airline['efficient_vrs_in']=[r.is_efficient for r in dea_vrs_in.result]
airline.set_index('name').loc[:,'vrs_in':]
# Out:
#         vrs_in  Aircraft_sl_vrs_in  Fuel_sl_vrs_in  Employee_sl_vrs_in  \
# name
# A     1.000000                -0.0           -0.00               -0.00
# B     1.000000                 0.0            0.00                0.00
# C     1.000000                 0.0            0.00                0.00
# D     0.900000                 0.0          178.80             1599.70
# E     0.995561                -0.0            0.00             4359.86
# F     1.000000                -0.0           -0.00                0.00
# G     1.000000                -0.0            0.00                0.00
# I     1.000000                -0.0            0.00               -0.00
# J     1.000000                 0.0            0.00               -0.00
# K     0.886279                 0.0          186.93               89.68
# L     1.000000                 0.0            0.00                0.00
# M     1.000000                -0.0            0.00                0.00
# N     0.848598                 0.0            0.00             1627.04
#
#       Passenger_sl_vrs_in  Freight_sl_vrs_in  efficient_vrs_in
# name
# A                    0.00               0.00             False
# B                    0.00               0.00             False
# C                   -0.00              -0.00             False
# D                 1592.00              27.00             False
# E                    0.00            3509.07             False
# F                    0.00               0.00             False
# G                    0.00               0.00             False
# I                    0.00               0.00             False
# J                    0.00               0.00             False
# K                 1041.48               0.00             False
# L                    0.00              -0.00              True
# M                    0.00              -0.00             False
# N                    0.00             697.90             False

# %%
# !pip install py4etrics

# %%
import numpy as np # linear algebra
from py4etrics import tobit
import statsmodels.api as sm

# %%
np.where(airline['vrs_in']==1, 1, 0)
# Out:
# array([1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 1, 1, 0])

# %%
airline.loc[:,'Aircraft':'Freight']
# Out:
# Index(['Aircraft', 'Fuel', 'Employee', 'Passenger', 'Freight'], dtype='object')

# %%
cens = np.where(airline['vrs_in']==1, 1, 0)#1 #airline['vrs_in']#.values
endog = airline.loc[:,'vrs_in']
exog = airline.loc[:,'Aircraft':'Freight']

tobit_res = tobit.Tobit(endog, exog, cens,right=1).fit()
tobit_res.summary()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.791458
#          Iterations: 459
#          Function evaluations: 700
# /Users/JoseManuel/opt/anaconda3/envs/ASIES/lib/python3.11/site-packages/statsmodels/base/model.py:595: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                               Tobit Regression Results
# ===================================================================================
# Dep. Variable:                      crs_in   Pseudo R-squ:                   -1.581
# Method:                 Maximum Likelihood   Log-Likelihood:                  -10.3
# No. Observations:                       13   LL-Null:                          -4.0
# No. Uncensored Obs:                      7   LL-Ratio:                        -12.6
# No. Left-censored Obs:                   0   LLR p-value:                     1.000
# No. Right-censored Obs:                  6   AIC:                              28.6
# Df Residuals:                            8   BIC:                              30.8
# Df Model:                                4   Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Aircraft       0.0046        nan        nan        nan         nan         nan
# Fuel          -0.0001        nan        nan        nan         nan         nan
# Employee   -1.138e-06        nan        nan        nan         nan         nan
# Passenger  -5.874e-06        nan        nan        nan         nan         nan
# Freight    -9.612e-06        nan        nan        nan         nan         nan
# Log(Sigma)    -0.4502        nan        nan        nan         nan         nan
# ==============================================================================
# """

# %%
airline.to_csv('airline_all.csv')
